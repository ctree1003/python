# %%
# %matplotlib inline
#Labraries for basic use
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
sns.set(style="ticks")

# %%
lego = pd.read_csv("C:/Users/student/Downloads/lego_sets.csv/lego_sets.csv")

# %%
lego.head()
# Out:
#    ages  list_price  num_reviews  piece_count  play_star_rating  \
# 0  6-12       29.99          2.0        277.0               4.0
# 1  6-12       19.99          2.0        168.0               4.0
# 2  6-12       12.99         11.0         74.0               4.3
# 3   12+       99.99         23.0       1032.0               3.6
# 4   12+       79.99         14.0        744.0               3.2
#
#                                            prod_desc  prod_id  \
# 0  Catapult into action and take back the eggs fr...  75823.0
# 1  Launch a flying attack and rescue the eggs fro...  75822.0
# 2  Chase the piggy with lightning-fast Chuck and ...  75821.0
# 3  Explore the architecture of the United States ...  21030.0
# 4  Recreate the Solomon R. Guggenheim Museum® wit...  21035.0
#
#                                       prod_long_desc review_difficulty  \
# 0  Use the staircase catapult to launch Red into ...           Average
# ...

# %%
lego.isna().sum()
# Out:
# ages                    0
# list_price              0
# num_reviews          1620
# piece_count             0
# play_star_rating     1775
# prod_desc             377
# prod_id                 0
# prod_long_desc          0
# review_difficulty    2055
# set_name                0
# star_rating          1620
# theme_name              3
# val_star_rating      1795
# country                 0
# dtype: int64

# %%
lego_na = lego.dropna(axis = 0)

# %%
lego_na.isna().sum()
# Out:
# ages                 0
# list_price           0
# num_reviews          0
# piece_count          0
# play_star_rating     0
# prod_desc            0
# prod_id              0
# prod_long_desc       0
# review_difficulty    0
# set_name             0
# star_rating          0
# theme_name           0
# val_star_rating      0
# country              0
# dtype: int64

# %%
lego=lego_na.drop(lego.columns[[2,5,6,7,9,11,12,13]], axis=1)

# %%
lego.head()
# Out:
#    ages  list_price  piece_count  play_star_rating review_difficulty  \
# 0  6-12       29.99        277.0               4.0           Average
# 1  6-12       19.99        168.0               4.0              Easy
# 2  6-12       12.99         74.0               4.3              Easy
# 3   12+       99.99       1032.0               3.6           Average
# 4   12+       79.99        744.0               3.2       Challenging
#
#    star_rating
# 0          4.5
# 1          5.0
# 2          4.3
# 3          4.6
# 4          4.6

# %%
X = lego.loc[:,"ages":]
y = lego["list_price"]

# %%
sns.pairplot(X, hue="review_difficulty")

# %%
sns.lineplot(x='piece_count', y='list_price', data=lego)

# %%
sns.boxplot(x='review_difficulty', y='list_price', data=lego)

# %%
sns.lineplot(x='review_difficulty', y='list_price', data=lego)
